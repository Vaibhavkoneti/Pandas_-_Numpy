# %% [markdown]
# # Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_wac = pd.read_csv("world_alcohol - world_alcohol.csv")
df_wac.iloc[:,1].unique()
# Out:
# array(['Western Pacific', 'Americas', 'Africa', 'Eastern Mediterranean',
#        'Europe', 'South-East Asia'], dtype=object)

# %%
reg = ['Africa', 'Eastern Mediterranean', 'Europe']
df_wac_reg = df_wac[df_wac.iloc[:,1]. isin(reg)]
df_wac_reg.iloc[:,1].unique()
# Out:
# array(['Africa', 'Eastern Mediterranean', 'Europe'], dtype=object)

# %% [markdown]
# # Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
df_wac_not_reg=df_wac[~df_wac.iloc[:,1].isin(reg)]
df_wac.iloc[:,3]
# Out:
# 0      Wine
# 1     Other
# 2      Wine
# 3      Beer
# 4      Beer
#       ...
# 95    Other
# 96     Wine
# 97     Wine
# 98     Wine
# 99     Wine
# Name: Beverage Types, Length: 100, dtype: object

# %% [markdown]
# # Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset

# %%
df_wac_filtered = df_wac[(df_wac.iloc[:,4] > 0.5) & (df_wac.iloc[:,4] < 2.50)]

# %% [markdown]
# # Write a Pandas program to find number of consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
df_wac[(df_wac.iloc[:,3] == 'Wine') & (df_wac.iloc[:,4] > 2)]
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %% [markdown]
# # Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
df_wac.filter(regex='0$', axis=0)
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# 60           0.00
# 70           1.02
# 80           0.84
# 90           0.01

# %% [markdown]
# # Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset.

# %%
df_cons_col = df_wac.loc[:,"Country":"Display Value"]
print("\nSelect rows with Index label 0 to 9 with specific columns:")
df_cons_col.loc[0:9,["Country","Display Value"]]
# Out:
# Select rows with Index label 0 to 9 with specific columns:
#                  Country  Display Value
# 0               Viet Nam           0.00
# 1                Uruguay           0.50
# 2           Cte d'Ivoire           1.62
# 3               Colombia           4.27
# 4  Saint Kitts and Nevis           1.98
# 5              Guatemala           0.00
# 6              Mauritius           0.13
# 7                 Angola           0.39
# 8    Antigua and Barbuda           1.55
# 9                Nigeria           6.10

# %% [markdown]
# # Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
df_wac_row_filt=df_wac.iloc[2:,:]
df_wac_row_filt.iloc[lambda x : x.index % 5 == 0]
# Out:
#     Year             WHO region                           Country  \
# 5   1987               Americas                         Guatemala
# 10  1987                 Africa                          Botswana
# 15  1987                 Africa                     Guinea-Bissau
# 20  1986        South-East Asia                           Myanmar
# 25  1984  Eastern Mediterranean                           Tunisia
# 30  1986                 Africa                      Sierra Leone
# 35  1985               Americas             Saint Kitts and Nevis
# 40  1987                 Europe                           Austria
# 45  1989                 Africa                          Zimbabwe
# 50  1985                 Europe                       Switzerland
# 55  1989               Americas                          Suriname
# 60  1987  Eastern Mediterranean        Iran (Islamic Republic of)
# 65  1989  Eastern Mediterranean                           Somalia
# 70  1986                 Africa                        Madagascar
# 75  1989  Eastern Mediterranean                       Afghanistan
# 80  1985                 Africa                            Malawi
# 85  1985                 Africa  Democratic Republic of the Congo
# 90  1989                 Africa                            Malawi
# 95  1984                 Africa                             Niger
#
#    Beverage Types  Display Value
# 5           Other           0.00
# 10           Wine           0.20
# 15           Wine           0.07
# 20           Wine           0.00
# 25          Other           0.00
# 30          Other           4.48
# 35        Spirits           2.24
# 40        Spirits           1.90
# 45           Beer           0.19
# 50          Other           0.30
# 55           Wine           0.04
# 60          Other           0.00
# 65           Beer           0.00
# 70        Spirits           1.02
# 75          Other           0.00
# 80          Other           0.84
# 85           Wine           0.01
# 90           Wine           0.01
# 95          Other           0.00

# %% [markdown]
# # Write a Pandas program to split the following dataframe into groups based on school code. Also check the type of GroupBy object.
#
# student_data = pd.DataFrame({
#     'school_code': ['s001','s002','s003','s001','s002','s004'],
#     'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
#     'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
#     'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
#     'age': [12, 12, 13, 13, 14, 12],
#     'height': [173, 192, 186, 167, 151, 159],
#     'weight': [35, 32, 33, 30, 31, 32],
#     'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
#     index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
# student_data.head(10)

# %%
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
student_data.head(10)
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
s001 =student_data.groupby('school_code').get_group('s001')
s002 =student_data.groupby('school_code').get_group('s002')
s003 =student_data.groupby('school_code').get_group('s003')
s004 =student_data.groupby('school_code').get_group('s004')
print(s001.dtypes)
# Out:
# school_code       object
# class             object
# name              object
# date_Of_Birth     object
# age                int64
# height             int64
# weight             int64
# address           object
# dtype: object

# %% [markdown]
# # Write a Pandas program to split the following dataframe by school code and get mean, min, and max value of age for each school.

# %%
print(student_data.groupby('school_code').mean())
print(student_data.groupby('school_code').min())
print(student_data.groupby('school_code').max())
# Out:
#               age  height  weight
# school_code
# s001         12.5   170.0    32.5
# s002         13.0   171.5    31.5
# s003         13.0   186.0    33.0
# s004         12.0   159.0    32.0
#             class            name date_Of_Birth   age  height  weight  address
# school_code
# s001            V  Alberto Franco     15/05/2002   12     167      30  street1
# s002            V    Gino Mcneill     11/05/2002   12     151      31  street2
# s003           VI     Ryan Parkes     16/02/1999   13     186      33  street3
# s004           VI    David Parkes     15/09/1997   12     159      32  street4
#             class          name date_Of_Birth   age  height  weight  address
# school_code
# s001           VI  Eesha Hinton     25/09/1998   13     173      35  street1
# s002            V  Gino Mcneill     17/05/2002   14     192      32  street2
# s003           VI   Ryan Parkes     16/02/1999   13     186      33  street3
# s004           VI  David Parkes     15/09/1997   12     159      32  street4

# %% [markdown]
# # Write a Pandas program to split the following given dataframe into groups based on school code and class.

# %%
student_data.groupby(['school_code','class']).first()
# Out:
#                              name date_Of_Birth   age  height  weight  address
# school_code class
# s001        V      Alberto Franco     15/05/2002   12     173      35  street1
#             VI       Eesha Hinton     25/09/1998   13     167      30  street1
# s002        V        Gino Mcneill     17/05/2002   12     192      32  street2
# s003        VI        Ryan Parkes     16/02/1999   13     186      33  street3
# s004        VI       David Parkes     15/09/1997   12     159      32  street4

# %% [markdown]
# # Create a dataframe of ten rows, four columns with random values. Convert some values to nan values. Write a Pandas program which will highlight the nan values.

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=list('ABCD'))
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 0] = np.nan
df
# Out:
#           A         B         C         D
# 0  0.819432 -1.295141       NaN -0.507268
# 1 -0.713854 -0.407814 -0.462270 -0.707695
# 2 -1.462874 -0.544141 -0.968122  1.500069
# 3  0.279623 -0.538594  1.154416       NaN
# 4 -0.086548       NaN -0.423996 -0.401282
# 5 -1.395693 -0.478502 -0.037545  0.591816
# 6 -0.186243 -0.558061  0.954507  1.771039
# 7  0.125597 -0.877219 -0.283743 -0.817107
# 8 -1.934501  1.260948 -2.226112  0.574497
# 9       NaN -0.420328 -1.728581 -0.001691

# %% [markdown]
# # Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.

# %%
def highlight_cols(df):
    df_1 = df.copy()
    df_1.loc[:,:] = 'background-color: red'
    df_1[['B','D']] = 'background-color: grey'
    return df_1 
df.style.apply(highlight_cols, axis=None)
# Out:
# <style type="text/css">
# #T_7c416_row0_col0, #T_7c416_row0_col2, #T_7c416_row1_col0, #T_7c416_row1_col2, #T_7c416_row2_col0, #T_7c416_row2_col2, #T_7c416_row3_col0, #T_7c416_row3_col2, #T_7c416_row4_col0, #T_7c416_row4_col2, #T_7c416_row5_col0, #T_7c416_row5_col2, #T_7c416_row6_col0, #T_7c416_row6_col2, #T_7c416_row7_col0, #T_7c416_row7_col2, #T_7c416_row8_col0, #T_7c416_row8_col2, #T_7c416_row9_col0, #T_7c416_row9_col2 {
#   background-color: red;
# }
# #T_7c416_row0_col1, #T_7c416_row0_col3, #T_7c416_row1_col1, #T_7c416_row1_col3, #T_7c416_row2_col1, #T_7c416_row2_col3, #T_7c416_row3_col1, #T_7c416_row3_col3, #T_7c416_row4_col1, #T_7c416_row4_col3, #T_7c416_row5_col1, #T_7c416_row5_col3, #T_7c416_row6_col1, #T_7c416_row6_col3, #T_7c416_row7_col1, #T_7c416_row7_col3, #T_7c416_row8_col1, #T_7c416_row8_col3, #T_7c416_row9_col1, #T_7c416_row9_col3 {
#   background-color: grey;
# }
# </style>
# <table id="T_7c416">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c416_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7c416_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7c416_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7c416_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c416_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c416_row0_col0" class="data row0 col0" >0.819432</td>
#       <td id="T_7c416_row0_col1" class="data row0 col1" >-1.295141</td>
#       <td id="T_7c416_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_7c416_row0_col3" class="data row0 col3" >-0.507268</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c416_row1_col0" class="data row1 col0" >-0.713854</td>
#       <td id="T_7c416_row1_col1" class="data row1 col1" >-0.407814</td>
#       <td id="T_7c416_row1_col2" class="data row1 col2" >-0.462270</td>
#       <td id="T_7c416_row1_col3" class="data row1 col3" >-0.707695</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c416_row2_col0" class="data row2 col0" >-1.462874</td>
#       <td id="T_7c416_row2_col1" class="data row2 col1" >-0.544141</td>
#       <td id="T_7c416_row2_col2" class="data row2 col2" >-0.968122</td>
#       <td id="T_7c416_row2_col3" class="data row2 col3" >1.500069</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c416_row3_col0" class="data row3 col0" >0.279623</td>
#       <td id="T_7c416_row3_col1" class="data row3 col1" >-0.538594</td>
#       <td id="T_7c416_row3_col2" class="data row3 col2" >1.154416</td>
#       <td id="T_7c416_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c416_row4_col0" class="data row4 col0" >-0.086548</td>
#       <td id="T_7c416_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_7c416_row4_col2" class="data row4 col2" >-0.423996</td>
#       <td id="T_7c416_row4_col3" class="data row4 col3" >-0.401282</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c416_row5_col0" class="data row5 col0" >-1.395693</td>
#       <td id="T_7c416_row5_col1" class="data row5 col1" >-0.478502</td>
#       <td id="T_7c416_row5_col2" class="data row5 col2" >-0.037545</td>
#       <td id="T_7c416_row5_col3" class="data row5 col3" >0.591816</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c416_row6_col0" class="data row6 col0" >-0.186243</td>
#       <td id="T_7c416_row6_col1" class="data row6 col1" >-0.558061</td>
#       <td id="T_7c416_row6_col2" class="data row6 col2" >0.954507</td>
#       <td id="T_7c416_row6_col3" class="data row6 col3" >1.771039</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c416_row7_col0" class="data row7 col0" >0.125597</td>
#       <td id="T_7c416_row7_col1" class="data row7 col1" >-0.877219</td>
#       <td id="T_7c416_row7_col2" class="data row7 col2" >-0.283743</td>
#       <td id="T_7c416_row7_col3" class="data row7 col3" >-0.817107</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c416_row8_col0" class="data row8 col0" >-1.934501</td>
#       <td id="T_7c416_row8_col1" class="data row8 col1" >1.260948</td>
#       <td id="T_7c416_row8_col2" class="data row8 col2" >-2.226112</td>
#       <td id="T_7c416_row8_col3" class="data row8 col3" >0.574497</td>
#     </tr>
#     <tr>
#       <th id="T_7c416_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c416_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_7c416_row9_col1" class="data row9 col1" >-0.420328</td>
#       <td id="T_7c416_row9_col2" class="data row9 col2" >-1.728581</td>
#       <td id="T_7c416_row9_col3" class="data row9 col3" >-0.001691</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Write a Pandas program to display the dataframe in Heatmap style.
df_heat = sns.heatmap(df.corr(),annot = True)
